# %%
# Dependencies and Setup

# visualizations
import matplotlib.pyplot as plt
import seaborn as sns

#data science - standard library
import pandas as pd
import numpy as np

#requests
import requests
from pprint import pprint
import time

#regression
from scipy.stats import linregress
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Lane_cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 646

# %%
cities_sub=cities[0:5]
cities_sub
# Out:
# ['busselton', 'misratah', 'qaanaaq', 'hobart', 'butaritari']

# %%
#init lists to hold parsed data
lats = []
longs = []
temps = []
humid = []
windSpeed = []
cloudiness = []
cities_found = []
countries = []

for i in range(len(cities)):
    #get the city
    city = cities[i]
    
    #create the url
    units = "imperial"
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&units={units}&appid={weather_api_key}"
#     print(url)

    #make the request
    response = requests.get(url)
#     print(response.status_code)
    
    #error check
    if response.status_code == 200:
        data = response.json()
#         pprint(data)
        
        try:
            lat = data["coord"]["lat"]
            long = data["coord"]["lon"]
            temp = data["main"]["temp"]
            humidity = data["main"]["humidity"]
            speed = data["wind"]["speed"]
            clouds = data["clouds"]["all"]
            city_name = data["name"]
            country = data["sys"]["country"]

            #save the data
            lats.append(lat)
            longs.append(long)
            temps.append(temp)
            humid.append(humidity)
            windSpeed.append(speed)
            cloudiness.append(clouds)
            cities_found.append(city_name)
            countries.append(country)
            
        except Exception as e:
            print(f"Through exception for city {city}: {e}")
    
    elif response.status_code == 404:
        print(f"Missing data in API for {city}")
    else:
        print(response.status_code)
        print("The API is broken.")
        
    #print every 5
    if (i % 5 == 0):
        print(f"Data gathered for: {i} of {len(cities)}")
    
    #sleep for requests
        time.sleep(1)
        
# make the dataframe
df = pd.DataFrame()
df["City"] = cities_found
df["Country"] = countries
df["Latitude"] = lats
df["Longitude"] = longs
df["Temperature"] = temps
df["Humidity"] = humid
df["Wind Speed"] = windSpeed
df["Cloudiness"] = cloudiness

df.head(10)
# Out:
# Data gathered for: 0 of 646
# Data gathered for: 5 of 646
# Data gathered for: 10 of 646
# Missing data in API for phnum penh
# Data gathered for: 15 of 646
# Data gathered for: 20 of 646
# Missing data in API for samusu
# Data gathered for: 25 of 646
# Missing data in API for marcona
# Data gathered for: 30 of 646
# Data gathered for: 35 of 646
# Missing data in API for amderma
# Data gathered for: 40 of 646
# Data gathered for: 45 of 646
# Missing data in API for illoqqortoormiut
# Missing data in API for mys shmidta
# Data gathered for: 50 of 646
# Data gathered for: 55 of 646
# Missing data in API for tumannyy
# Data gathered for: 60 of 646
# Data gathered for: 65 of 646
# Data gathered for: 70 of 646
# Data gathered for: 75 of 646
# Data gathered for: 80 of 646
# Data gathered for: 85 of 646
# Data gathered for: 90 of 646
# Data gathered for: 95 of 646
# Data gathered for: 100 of 646
# Data gathered for: 105 of 646
# Data gathered for: 110 of 646
# Missing data in API for witrivier
# Data gathered for: 115 of 646
# Missing data in API for malwan
# Data gathered for: 120 of 646
# Data gathered for: 125 of 646
# Data gathered for: 130 of 646
# Missing data in API for taolanaro
# Missing data in API for tabarqah
# Data gathered for: 135 of 646
# Data gathered for: 140 of 646
# Missing data in API for urdzhar
# Data gathered for: 145 of 646
# Data gathered for: 150 of 646
# Data gathered for: 155 of 646
# Data gathered for: 160 of 646
# Missing data in API for barentsburg
# Data gathered for: 165 of 646
# Data gathered for: 170 of 646
# Data gathered for: 175 of 646
# Missing data in API for umzimvubu
# Data gathered for: 180 of 646
# Missing data in API for samalaeulu
# Data gathered for: 185 of 646
# Data gathered for: 190 of 646
# Missing data in API for kurobe
# Data gathered for: 195 of 646
# Data gathered for: 200 of 646
# Data gathered for: 205 of 646
# Missing data in API for vaitupu
# Missing data in API for cagayan de tawi-tawi
# Data gathered for: 210 of 646
# Missing data in API for katha
# Data gathered for: 215 of 646
# Data gathered for: 220 of 646
# Missing data in API for hunza
# Missing data in API for saleaula
# Data gathered for: 225 of 646
# Data gathered for: 230 of 646
# Data gathered for: 235 of 646
# Missing data in API for tsihombe
# Data gathered for: 240 of 646
# Data gathered for: 245 of 646
# Missing data in API for bargal
# Data gathered for: 250 of 646
# Data gathered for: 255 of 646
# Data gathered for: 260 of 646
# Data gathered for: 265 of 646
# Data gathered for: 270 of 646
# Data gathered for: 275 of 646
# Missing data in API for attawapiskat
# Data gathered for: 280 of 646
# Missing data in API for bur gabo
# Data gathered for: 285 of 646
# Missing data in API for andevoranto
# Data gathered for: 290 of 646
# Data gathered for: 295 of 646
# Data gathered for: 300 of 646
# Data gathered for: 305 of 646
# Missing data in API for ruatoria
# Data gathered for: 310 of 646
# Data gathered for: 315 of 646
# Missing data in API for jabiru
# Data gathered for: 320 of 646
# Data gathered for: 325 of 646
# Data gathered for: 330 of 646
# Data gathered for: 335 of 646
# Data gathered for: 340 of 646
# Missing data in API for gazni
# Data gathered for: 345 of 646
# Missing data in API for hihifo
# Missing data in API for sentyabrskiy
# Missing data in API for belushya guba
# Data gathered for: 350 of 646
# Data gathered for: 355 of 646
# Data gathered for: 360 of 646
# Missing data in API for mocambique
# Data gathered for: 365 of 646
# Data gathered for: 370 of 646
# Data gathered for: 375 of 646
# Missing data in API for sataua
# Data gathered for: 380 of 646
# Missing data in API for dujuma
# Data gathered for: 385 of 646
# Data gathered for: 390 of 646
# Missing data in API for ahumada
# Missing data in API for kamenskoye
# Data gathered for: 395 of 646
# Data gathered for: 400 of 646
# Missing data in API for grand river south east
# Data gathered for: 405 of 646
# Data gathered for: 410 of 646
# Missing data in API for halalo
# Data gathered for: 415 of 646
# Missing data in API for palabuhanratu
# Data gathered for: 420 of 646
# Data gathered for: 425 of 646
# Missing data in API for sint michiel
# Data gathered for: 430 of 646
# Missing data in API for tabiauea
# Data gathered for: 435 of 646
# Data gathered for: 440 of 646
# Missing data in API for haibowan
# Data gathered for: 445 of 646
# Data gathered for: 450 of 646
# Data gathered for: 455 of 646
# Data gathered for: 460 of 646
# Data gathered for: 465 of 646
# Data gathered for: 470 of 646
# Data gathered for: 475 of 646
# Missing data in API for garm
# Missing data in API for gurgan
# Data gathered for: 480 of 646
# Data gathered for: 485 of 646
# Missing data in API for ambodifototra
# Data gathered for: 490 of 646
# Missing data in API for phan rang
# Data gathered for: 495 of 646
# Data gathered for: 500 of 646
# Data gathered for: 505 of 646
# Data gathered for: 510 of 646
# Missing data in API for bolungarvik
# Data gathered for: 515 of 646
# Data gathered for: 520 of 646
# Data gathered for: 525 of 646
# Data gathered for: 530 of 646
# Data gathered for: 535 of 646
# Data gathered for: 540 of 646
# Data gathered for: 545 of 646
# Missing data in API for bababe
# Data gathered for: 550 of 646
# Missing data in API for fort saint john
# Data gathered for: 555 of 646
# Data gathered for: 560 of 646
# Missing data in API for toliary
# Data gathered for: 565 of 646
# Data gathered for: 570 of 646
# Missing data in API for nizhneyansk
# Data gathered for: 575 of 646
# Data gathered for: 580 of 646
# Data gathered for: 585 of 646
# Data gathered for: 590 of 646
# Data gathered for: 595 of 646
# Missing data in API for karakendzha
# Data gathered for: 600 of 646
# Missing data in API for yirol
# Data gathered for: 605 of 646
# Data gathered for: 610 of 646
# Data gathered for: 615 of 646
# Missing data in API for sinkat
# Data gathered for: 620 of 646
# Missing data in API for burica
# Data gathered for: 625 of 646
# Missing data in API for inderborskiy
# Data gathered for: 630 of 646
# Data gathered for: 635 of 646
# Missing data in API for mendahara
# Missing data in API for mullaitivu
# Data gathered for: 640 of 646
# Data gathered for: 645 of 646
#            City Country  Latitude  Longitude  Temperature  Humidity  \
# 0     Busselton      AU    -33.65     115.33        57.61        98
# 1      Misratah      LY     32.38      15.09        69.39        65
# 2       Qaanaaq      GL     77.48     -69.36       -12.33        70
# 3        Hobart      AU    -42.88     147.33        58.15        54
# 4    Butaritari      KI      3.07     172.79        81.34        72
# 5      Gisborne      NZ    -38.65     178.00        73.99        53
# 6        Faanui      PF    -16.48    -151.75        79.20        77
# 7        Albany      US     42.60     -73.97        57.76        54
# 8  Punta Arenas      CL    -53.15     -70.92        57.09        58
# 9       Fortuna      US     40.60    -124.16        53.76        62
#
#    Wind Speed  Cloudiness
# 0        3.15          38
# 1       10.96           1
# 2        8.90           0
# 3        5.82          20
# 4       11.63          92
# 5        8.01          64
# 6       10.54          76
# 7        3.76          90
# 8       32.21          40
# 9       17.22          75

# %%
df.to_csv(output_data_file, index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 587 entries, 0 to 586
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         587 non-null    object
#  1   Country      587 non-null    object
#  2   Latitude     587 non-null    float64
#  3   Longitude    587 non-null    float64
#  4   Temperature  587 non-null    float64
#  5   Humidity     587 non-null    int64
#  6   Wind Speed   587 non-null    float64
#  7   Cloudiness   587 non-null    int64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 36.8+ KB
